# %%
import pandas as pd
df2 = pd.read_csv("XRP.csv")
df = df2.copy()
df.head()
# Out:
#          Date   Price    Open    High     Low     Vol. Change %
# 0  06/19/2025  2.1474  2.1704  2.1828  2.1446  223.99M   -1.06%
# 1  06/18/2025  2.1704  2.1591  2.1802  2.1189  298.05M    0.53%
# 2  06/17/2025  2.1590  2.2367  2.2563  2.1431  459.24M   -3.40%
# 3  06/16/2025  2.2349  2.1656  2.3362  2.1517  542.39M    3.20%
# 4  06/15/2025  2.1656  2.1396  2.1752  2.1383  136.20M    1.21%

# %%
df.describe().T
# Out:
#         count      mean       std     min     25%     50%     75%     max
# Price  3801.0  0.497003  0.560825  0.0036  0.1900  0.3674  0.5919  3.2914
# Open   3801.0  0.496353  0.559858  0.0036  0.1898  0.3668  0.5913  3.2912
# High   3801.0  0.516410  0.584878  0.0036  0.1959  0.3789  0.6138  3.3954
# Low    3801.0  0.475152  0.533837  0.0030  0.1831  0.3512  0.5701  3.1794

# %%
df.isnull().sum()
# Out:
# Date          0
# Price         0
# Open          0
# High          0
# Low           0
# Vol.        199
# Change %      0
# dtype: int64

# %%
df.tail()
# Out:
#             Date   Price    Open    High     Low Vol. Change %
# 3796  01/26/2015  0.0147  0.0170  0.0175  0.0147  NaN  -13.59%
# 3797  01/25/2015  0.0170  0.0174  0.0174  0.0156  NaN   -2.24%
# 3798  01/24/2015  0.0174  0.0160  0.0174  0.0150  NaN    8.69%
# 3799  01/23/2015  0.0160  0.0160  0.0170  0.0160  NaN    0.00%
# 3800  01/22/2015  0.0160  0.0152  0.0175  0.0152  NaN    5.19%

# %%
df.isnull().sum()
# Out:
# Date          0
# Price         0
# Open          0
# High          0
# Low           0
# Vol.        199
# Change %      0
# dtype: int64

# %%
df.head()
# Out:
#          Date   Price    Open    High     Low  Vol. Change %
# 0  06/19/2025  2.1474  2.1704  2.1828  2.1446   NaN   -1.06%
# 1  06/18/2025  2.1704  2.1591  2.1802  2.1189   NaN    0.53%
# 2  06/17/2025  2.1590  2.2367  2.2563  2.1431   NaN   -3.40%
# 3  06/16/2025  2.2349  2.1656  2.3362  2.1517   NaN    3.20%
# 4  06/15/2025  2.1656  2.1396  2.1752  2.1383   NaN    1.21%

# %%
def convert_units(value):
    if isinstance(value, str):
        value = value.strip()  # Baştaki/sondaki boşlukları temizle
        if 'K' in value:
            return float(value.replace('K', '')) * 1000
        elif 'M' in value:
            return float(value.replace('M', '')) * 1_000_000
        elif 'B' in value:
            return float(value.replace('B', '')) * 1_000_000_000
        else:
            return float(value)  # Kısaltma yoksa direkt float'a çevir
    return value  # Zaten sayısal bir değerse olduğu gibi döndür
    
df['Vol.'] = df['Vol.'].apply(convert_units)

# %%
df.dtypes
# Out:
# Date         object
# Price       float64
# Open        float64
# High        float64
# Low         float64
# Vol.        float64
# Change %     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date          0
# Price         0
# Open          0
# High          0
# Low           0
# Vol.        199
# Change %      0
# dtype: int64

# %%
# "Hac." sütununu dönüştürmek için fonksiyon
def convert_volume(value):
    #value = value.replace(',', '.')  # Virgülü noktaya çevir
    if value.endswith('B'):
        return float(value[:-1]) * 1_000_000_000
    elif value.endswith('M'):
        return float(value[:-1]) * 1_000_000  # "M" ise milyonla çarp
    elif value.endswith('K'):
        return float(value[:-1]) * 1_000      # "K" ise binle çarp
    else:
        return float(value)                    # Kısaltma yoksa direkt float

# Fonksiyonu "Hac." sütununa uygulama
df['Vol.'] = df['Vol.'].apply(convert_volume)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 14
#      11         return float(value)                    # Kısaltma yoksa direkt float
#      13 # Fonksiyonu "Hac." sütununa uygulama
# ---> 14 df['Vol.'] = df['Vol.'].apply(convert_volume)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\apply.py:1209, in SeriesApply.apply(self)
#    1206     return self.apply_compat()
#    1208 # self.func is Callable
# -> 1209 return self.apply_standard()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\apply.py:1289, in SeriesApply.apply_standard(self)
#    1283 # row-wise access
#    1284 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1285 # we need to give `na_action="ignore"` for categorical data.
#    1286 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1287 #  Categorical (GH51645).
#    1288 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1289 mapped = obj._map_values(
#    1290     mapper=curried, na_action=action, convert=self.convert_dtype
#    1291 )
#    1293 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1294     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1295     #  See also GH#25959 regarding EA support
#    1296     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2926, in pandas._libs.lib.map_infer()
#
# Cell In[37], line 4, in convert_volume(value)
#       2 def convert_volume(value):
#       3     #value = value.replace(',', '.')  # Virgülü noktaya çevir
# ----> 4     if value.endswith('B'):
#       5         return float(value[:-1]) * 1_000_000_000
#       6     elif value.endswith('M'):
#
# AttributeError: 'float' object has no attribute 'endswith'

# %%
df.head()
# Out:
#          Date   Price    Open    High     Low         Vol. Change %
# 0  06/19/2025  2.1474  2.1704  2.1828  2.1446  223990000.0   -1.06%
# 1  06/18/2025  2.1704  2.1591  2.1802  2.1189  298050000.0    0.53%
# 2  06/17/2025  2.1590  2.2367  2.2563  2.1431  459240000.0   -3.40%
# 3  06/16/2025  2.2349  2.1656  2.3362  2.1517  542390000.0    3.20%
# 4  06/15/2025  2.1656  2.1396  2.1752  2.1383  136200000.0    1.21%

# %%
# "Tarih" sütununu datetime formatına çevirme
#df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')
df['Date'] = pd.to_datetime(df['Date'],format='mixed', dayfirst=False)
df.head()
# Out:
#         Date   Price    Open    High     Low         Vol. Change %
# 0 2025-06-19  2.1474  2.1704  2.1828  2.1446  223990000.0   -1.06%
# 1 2025-06-18  2.1704  2.1591  2.1802  2.1189  298050000.0    0.53%
# 2 2025-06-17  2.1590  2.2367  2.2563  2.1431  459240000.0   -3.40%
# 3 2025-06-16  2.2349  2.1656  2.3362  2.1517  542390000.0    3.20%
# 4 2025-06-15  2.1656  2.1396  2.1752  2.1383  136200000.0    1.21%

# %%
vol_ortalama = df['Vol.'].mean()
df['Vol.'].fillna(vol_ortalama, inplace=True)
# Eksik verileri kontrol etme
print(df.isnull().sum())

# Eksik verileri bir önceki değerle doldurma
#df = df.fillna(method='ffill')
# Out:
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Vol.        0
# Change %    0
# dtype: int64

# %%
# İlk birkaç satırı görüntüleme
print(df.head())

# Sütun tiplerini kontrol etme
print(df.dtypes)
# Out:
#         Date   Price    Open    High     Low         Vol. Change %
# 0 2025-06-19  2.1474  2.1704  2.1828  2.1446  223990000.0   -1.06%
# 1 2025-06-18  2.1704  2.1591  2.1802  2.1189  298050000.0    0.53%
# 2 2025-06-17  2.1590  2.2367  2.2563  2.1431  459240000.0   -3.40%
# 3 2025-06-16  2.2349  2.1656  2.3362  2.1517  542390000.0    3.20%
# 4 2025-06-15  2.1656  2.1396  2.1752  2.1383  136200000.0    1.21%
# Date        datetime64[ns]
# Price              float64
# Open               float64
# High               float64
# Low                float64
# Vol.               float64
# Change %            object
# dtype: object

# %%
# "Fark" sütununu sayısal değere dönüştürme
df['Change %'] = df['Change %'].str.replace('%', '')      # % sembolünü kaldır
df['Change %'] = df['Change %'].str.replace(',', '.')     # Virgülü noktaya çevir
df['Change %'] = df['Change %'].astype(float)             # Float'a dönüştür
# Dönüşüm sonrası kontrol
print(df['Change %'].head())
# Out:
# 0   -1.06
# 1    0.53
# 2   -3.40
# 3    3.20
# 4    1.21
# Name: Change %, dtype: float64

# %%
print(df.dtypes)
# Out:
# Date        datetime64[ns]
# Price              float64
# Open               float64
# High               float64
# Low                float64
# Vol.               float64
# Change %           float64
# dtype: object

# %%
# Tarih sütununun zaten datetime64[ns] formatında olduğunu varsayıyoruz
# Fiyat sütunlarını sayısal formata dönüştürme
#for col in ['Price', 'Open', 'High', 'Low']:
    #df[col] = df[col].str.replace(',', '.').astype(float)

for col in ['Price', 'Open', 'High', 'Low']:
    # Binlik ayırıcı noktaları kaldır (örneğin "1.001.30" → "1001.30" değil, bu veride anlam bozulabilir ama yine deneyelim)
    df[col] = df[col].str.replace('.', '', regex=False)  # Önce tüm noktaları kaldır
    # Daha sonra ondalık ayırıcının da noktadan farklı olduğunu varsayarsak değiştirebilirsin
    df[col] = df[col].str.replace(',', '.', regex=False)  # Virgülü noktaya çevir
    df[col] = df[col].astype(float)

# Dönüşüm sonrası sütun tiplerini kontrol etme
print(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 8
#       1 # Tarih sütununun zaten datetime64[ns] formatında olduğunu varsayıyoruz
#       2 # Fiyat sütunlarını sayısal formata dönüştürme
#       3 #for col in ['Price', 'Open', 'High', 'Low']:
#       4     #df[col] = df[col].str.replace(',', '.').astype(float)
#       6 for col in ['Price', 'Open', 'High', 'Low']:
#       7     # Binlik ayırıcı noktaları kaldır (örneğin "1.001.30" → "1001.30" değil, bu veride anlam bozulabilir ama yine deneyelim)
# ----> 8     df[col] = df[col].str.replace('.', '', regex=False)  # Önce tüm noktaları kaldır
#       9     # Daha sonra ondalık ayırıcının da noktadan farklı olduğunu varsayarsak değiştirebilirsin
#      10     df[col] = df[col].str.replace(',', '.', regex=False)  # Virgülü noktaya çevir
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:190, in StringMethods.__init__(self, data)
#     187 def __init__(self, data) -> None:
#     188     from pandas.core.arrays.string_ import StringDtype
# --> 190     self._inferred_dtype = self._validate(data)
#     191     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     192     self._is_string = isinstance(data.dtype, StringDtype)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:244, in StringMethods._validate(data)
#     241 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     243 if inferred_dtype not in allowed_types:
# --> 244     raise AttributeError("Can only use .str accessor with string values!")
#     245 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
df.describe().T
# Out:
#            count                           mean                  min  \
# Date        3801  2020-04-05 02:42:08.808208640  2015-01-22 00:00:00
# Price     3801.0                       0.497003               0.0036
# Open      3801.0                       0.496353               0.0036
# High      3801.0                        0.51641               0.0036
# Low       3801.0                       0.475152                0.003
# Vol.      3801.0               716499169.802887                  0.0
# Change %  3801.0                       0.467566               -63.11
#
#                           25%                  50%                  75%  \
# Date      2017-08-29 00:00:00  2020-04-05 00:00:00  2022-11-11 00:00:00
# Price                    0.19               0.3674               0.5919
# Open                   0.1898               0.3668               0.5913
# High                   0.1959               0.3789               0.6138
# Low                    0.1831               0.3512               0.5701
# Vol.              136570000.0          464590000.0          888150000.0
# Change %                -2.36                  0.0                  2.2
#
#                           max               std
# Date      2025-06-19 00:00:00               NaN
# Price                  3.2914          0.560825
# Open                   3.2912          0.559858
# High                   3.3954          0.584878
# Low                    3.1794          0.533837
# Vol.            13830000000.0  936948351.636073
# Change %               179.55          8.942916

# %%
df.dtypes
# Out:
# Date        datetime64[ns]
# Price              float64
# Open               float64
# High               float64
# Low                float64
# Vol.               float64
# Change %           float64
# dtype: object

# %%
#SMA (Simple Moving Average - Basit Hareketli Ortalama)
#EMA (Exponential Moving Average - Üssel Hareketli Ortalama)

# 10 günlük SMA ekleme
df['SMA_10'] = df['Price'].rolling(window=10).mean()

# 10 günlük EMA ekleme
df['EMA_10'] = df['Price'].ewm(span=10, adjust=False).mean()
df.head()
# Out:
#         Date   Price    Open    High     Low         Vol.  Change %  SMA_10  \
# 0 2025-06-19  2.1474  2.1704  2.1828  2.1446  223990000.0     -1.06     NaN
# 1 2025-06-18  2.1704  2.1591  2.1802  2.1189  298050000.0      0.53     NaN
# 2 2025-06-17  2.1590  2.2367  2.2563  2.1431  459240000.0     -3.40     NaN
# 3 2025-06-16  2.2349  2.1656  2.3362  2.1517  542390000.0      3.20     NaN
# 4 2025-06-15  2.1656  2.1396  2.1752  2.1383  136200000.0      1.21     NaN
#
#      EMA_10
# 0  2.147400
# 1  2.151582
# 2  2.152931
# 3  2.167834
# 4  2.167428

# %%
# 10 günlük SMA ekleme
df['SMA_10'] = df['Price'].rolling(window=10).mean()

# 10 günlük EMA ekleme
df['EMA_10'] = df['Price'].ewm(span=10, adjust=False).mean()
df.head()
# Out:
#         Date   Price    Open    High     Low         Vol.  Change %  SMA_10  \
# 0 2025-06-19  2.1474  2.1704  2.1828  2.1446  223990000.0     -1.06     NaN
# 1 2025-06-18  2.1704  2.1591  2.1802  2.1189  298050000.0      0.53     NaN
# 2 2025-06-17  2.1590  2.2367  2.2563  2.1431  459240000.0     -3.40     NaN
# 3 2025-06-16  2.2349  2.1656  2.3362  2.1517  542390000.0      3.20     NaN
# 4 2025-06-15  2.1656  2.1396  2.1752  2.1383  136200000.0      1.21     NaN
#
#      EMA_10
# 0  2.147400
# 1  2.151582
# 2  2.152931
# 3  2.167834
# 4  2.167428

# %%
df['SMA_10'] = df['SMA_10'].fillna(df['Price'].expanding().mean()) # ilk 10 gün ortalaması
df.head(20)
# Out:
#          Date   Price    Open    High     Low         Vol.  Change %  \
# 0  2025-06-19  2.1474  2.1704  2.1828  2.1446  223990000.0     -1.06
# 1  2025-06-18  2.1704  2.1591  2.1802  2.1189  298050000.0      0.53
# 2  2025-06-17  2.1590  2.2367  2.2563  2.1431  459240000.0     -3.40
# 3  2025-06-16  2.2349  2.1656  2.3362  2.1517  542390000.0      3.20
# 4  2025-06-15  2.1656  2.1396  2.1752  2.1383  136200000.0      1.21
# 5  2025-06-14  2.1396  2.1478  2.1782  2.1112  200490000.0     -0.38
# 6  2025-06-13  2.1478  2.1910  2.1910  2.0850  528790000.0     -1.97
# 7  2025-06-12  2.1910  2.2707  2.2729  2.1715  298380000.0     -3.51
# 8  2025-06-11  2.2707  2.3072  2.3377  2.2543  300230000.0     -1.59
# 9  2025-06-10  2.3073  2.3212  2.3258  2.2625  302290000.0     -0.59
# 10 2025-06-09  2.3210  2.2670  2.3285  2.2232  350130000.0      2.37
# 11 2025-06-08  2.2672  2.1771  2.2951  2.1670  306780000.0      4.14
# 12 2025-06-07  2.1771  2.1612  2.1907  2.1482  124920000.0      0.79
# 13 2025-06-06  2.1600  2.0941  2.1900  2.0834  270670000.0      3.15
# 14 2025-06-05  2.0941  2.2013  2.2262  2.0618  410980000.0     -4.87
# 15 2025-06-04  2.2013  2.2448  2.2654  2.1959  231790000.0     -1.94
# 16 2025-06-03  2.2448  2.1965  2.2807  2.1846  264120000.0      2.20
# 17 2025-06-02  2.1966  2.1793  2.2041  2.1365  268800000.0      0.81
# 18 2025-06-01  2.1790  2.1738  2.1876  2.1253  191240000.0      0.24
# 19 2025-05-31  2.1738  2.1412  2.2054  2.0814  308450000.0      1.61
#
#       SMA_10    EMA_10
# 0   2.147400  2.147400
# 1   2.158900  2.151582
# 2   2.158933  2.152931
# 3   2.177925  2.167834
# 4   2.175460  2.167428
# 5   2.169483  2.162368
# 6   2.166386  2.159720
# 7   2.169462  2.165407
# 8   2.180711  2.184551
# 9   2.193370  2.206869
# 10  2.210730  2.227620
# 11  2.220410  2.234816
# 12  2.222220  2.224323
# 13  2.214730  2.212628
# 14  2.207580  2.191077
# 15  2.213750  2.192936
# 16  2.223450  2.202366
# 17  2.224010  2.201317
# 18  2.214840  2.197260
# 19  2.201490  2.192994

# %%
from ta.momentum import RSIIndicator

#RSI (Relative Strength Index - Göreceli Güç Endeksi)
# 14 günlük RSI ekleme
rsi = RSIIndicator(close=df['Price'], window=14)
df['RSI_14'] = rsi.rsi()

# %%
#df['RSI_14'] = df['RSI_14'].fillna(df['RSI_14'].mean())

# İlk 30 günün RSI_14 ortalamasını hesapla (NaN hariç)
mean_first_20 = df.loc[:20, 'RSI_14'].mean()

# İlk 30 günün NaN değerlerini bu ortalama ile doldur
df.loc[:29, 'RSI_14'] = df.loc[:29, 'RSI_14'].fillna(mean_first_20)
df.head(20)
# Out:
#          Date   Price    Open    High     Low         Vol.  Change %  \
# 0  2025-06-19  2.1474  2.1704  2.1828  2.1446  223990000.0     -1.06
# 1  2025-06-18  2.1704  2.1591  2.1802  2.1189  298050000.0      0.53
# 2  2025-06-17  2.1590  2.2367  2.2563  2.1431  459240000.0     -3.40
# 3  2025-06-16  2.2349  2.1656  2.3362  2.1517  542390000.0      3.20
# 4  2025-06-15  2.1656  2.1396  2.1752  2.1383  136200000.0      1.21
# 5  2025-06-14  2.1396  2.1478  2.1782  2.1112  200490000.0     -0.38
# 6  2025-06-13  2.1478  2.1910  2.1910  2.0850  528790000.0     -1.97
# 7  2025-06-12  2.1910  2.2707  2.2729  2.1715  298380000.0     -3.51
# 8  2025-06-11  2.2707  2.3072  2.3377  2.2543  300230000.0     -1.59
# 9  2025-06-10  2.3073  2.3212  2.3258  2.2625  302290000.0     -0.59
# 10 2025-06-09  2.3210  2.2670  2.3285  2.2232  350130000.0      2.37
# 11 2025-06-08  2.2672  2.1771  2.2951  2.1670  306780000.0      4.14
# 12 2025-06-07  2.1771  2.1612  2.1907  2.1482  124920000.0      0.79
# 13 2025-06-06  2.1600  2.0941  2.1900  2.0834  270670000.0      3.15
# 14 2025-06-05  2.0941  2.2013  2.2262  2.0618  410980000.0     -4.87
# 15 2025-06-04  2.2013  2.2448  2.2654  2.1959  231790000.0     -1.94
# 16 2025-06-03  2.2448  2.1965  2.2807  2.1846  264120000.0      2.20
# 17 2025-06-02  2.1966  2.1793  2.2041  2.1365  268800000.0      0.81
# 18 2025-06-01  2.1790  2.1738  2.1876  2.1253  191240000.0      0.24
# 19 2025-05-31  2.1738  2.1412  2.2054  2.0814  308450000.0      1.61
#
#       SMA_10    EMA_10     RSI_14
# 0   2.147400  2.147400  48.247141
# 1   2.158900  2.151582  48.247141
# 2   2.158933  2.152931  48.247141
# 3   2.177925  2.167834  48.247141
# 4   2.175460  2.167428  48.247141
# 5   2.169483  2.162368  48.247141
# 6   2.166386  2.159720  48.247141
# 7   2.169462  2.165407  48.247141
# 8   2.180711  2.184551  48.247141
# 9   2.193370  2.206869  48.247141
# 10  2.210730  2.227620  48.247141
# 11  2.220410  2.234816  48.247141
# 12  2.222220  2.224323  48.247141
# 13  2.214730  2.212628  45.885760
# 14  2.207580  2.191077  38.559758
# 15  2.213750  2.192936  51.988333
# 16  2.223450  2.202366  56.174206
# 17  2.224010  2.201317  50.880795
# 18  2.214840  2.197260  49.062766
# 19  2.201490  2.192994  48.511241

# %%
df.dtypes
# Out:
# Date        datetime64[ns]
# Price              float64
# Open               float64
# High               float64
# Low                float64
# Vol.               float64
# Change %           float64
# SMA_10             float64
# EMA_10             float64
# RSI_14             float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Vol.        0
# Change %    0
# SMA_10      0
# EMA_10      0
# RSI_14      0
# dtype: int64

# %%
from ta.trend import MACD

#MACD (Moving Average Convergence Divergence) Hareketli Ortalama Yakınsama Iraksama göstergesidir
# MACD ekleme (12, 26, 9)
macd = MACD(close=df['Price'], window_slow=26, window_fast=12, window_sign=9)
df['MACD'] = macd.macd()          # MACD çizgisi
df['MACD_Signal'] = macd.macd_signal()  # Sinyal çizgisi
df['MACD_Diff'] = macd.macd_diff()      # Fark (histogram)

# %%
df.head(40)
# Out:
#          Date   Price    Open    High     Low          Vol.  Change %  \
# 0  2025-06-19  2.1474  2.1704  2.1828  2.1446  2.239900e+08     -1.06
# 1  2025-06-18  2.1704  2.1591  2.1802  2.1189  2.980500e+08      0.53
# 2  2025-06-17  2.1590  2.2367  2.2563  2.1431  4.592400e+08     -3.40
# 39 2025-05-11  2.3672  2.4636  2.4815  2.3298  4.318100e+08     -4.19
#
#       SMA_10    EMA_10     RSI_14      MACD  MACD_Signal  MACD_Diff
# 0   2.147400  2.147400  48.247141       NaN          NaN        NaN
# 1   2.158900  2.151582  48.247141       NaN          NaN        NaN
# 2   2.158933  2.152931  48.247141       NaN          NaN        NaN
# 3   2.177925  2.167834  48.247141       NaN          NaN        NaN
# 4   2.175460  2.167428  48.247141       NaN          NaN        NaN
# 5   2.169483  2.162368  48.247141       NaN          NaN        NaN
# 6   2.166386  2.159720  48.247141       NaN          NaN        NaN
# 7   2.169462  2.165407  48.247141       NaN          NaN        NaN
# 8   2.180711  2.184551  48.247141       NaN          NaN        NaN
# 9   2.193370  2.206869  48.247141       NaN          NaN        NaN
# 10  2.210730  2.227620  48.247141       NaN          NaN        NaN
# 11  2.220410  2.234816  48.247141       NaN          NaN        NaN
# 12  2.222220  2.224323  48.247141       NaN          NaN        NaN
# 13  2.214730  2.212628  45.885760       NaN          NaN        NaN
# 14  2.207580  2.191077  38.559758       NaN          NaN        NaN
# 15  2.213750  2.192936  51.988333       NaN          NaN        NaN
# 16  2.223450  2.202366  56.174206       NaN          NaN        NaN
# 17  2.224010  2.201317  50.880795       NaN          NaN        NaN
# 18  2.214840  2.197260  49.062766       NaN          NaN        NaN
# 19  2.201490  2.192994  48.511241       NaN          NaN        NaN
# 20  2.183330  2.183250  44.914271       NaN          NaN        NaN
# 21  2.181070  2.194404  55.725802       NaN          NaN        NaN
# 22  2.190820  2.208985  58.242728       NaN          NaN        NaN
# 23  2.206520  2.228624  61.568104       NaN          NaN        NaN
# 24  2.228190  2.243565  60.805564       NaN          NaN        NaN
# 25  2.242280  2.261499  63.285642  0.031996          NaN        NaN
# 26  2.250850  2.274045  61.718540  0.035788          NaN        NaN
# 27  2.260830  2.278109  57.267574  0.035631          NaN        NaN
# 28  2.286080  2.305998  67.322397  0.045879          NaN        NaN
# 29  2.308250  2.322271  63.064146  0.050514          NaN        NaN
# 30  2.329940  2.328458  58.709543  0.050442          NaN        NaN
# 31  2.343530  2.337921  60.521870  0.051742          NaN        NaN
# 32  2.359010  2.354553  63.963815  0.056071          NaN        NaN
# 33  2.362650  2.354344  55.818385  0.052761     0.047194   0.005568
# 34  2.369540  2.358954  57.820143  0.051665     0.048088   0.003577
# 35  2.373830  2.363708  58.238521  0.050648     0.048600   0.002048
# 36  2.395860  2.397724  68.547794  0.062492     0.051379   0.011114
# 37  2.424530  2.431429  70.097415  0.073637     0.055830   0.017806
# 38  2.436030  2.452351  66.121990  0.078609     0.060386   0.018223
# 39  2.433200  2.436869  50.894282  0.067306     0.061770   0.005536

# %%
for col in ['MACD', 'MACD_Signal', 'MACD_Diff']: # İlk günki değer ile dolduruldu
    first_value = df[col].iloc[33]
    df[col] = df[col].fillna(first_value)
df.isnull().sum()
# Out:
# Date           0
# Price          0
# Open           0
# High           0
# Low            0
# Vol.           0
# Change %       0
# SMA_10         0
# EMA_10         0
# RSI_14         0
# MACD           0
# MACD_Signal    0
# MACD_Diff      0
# dtype: int64

# %%
df.dtypes
# Out:
# Date           datetime64[ns]
# 34  2.369540  2.358954  57.820143  0.051665     0.048088   0.003577
# 35  2.373830  2.363708  58.238521  0.050648     0.048600   0.002048
# 36  2.395860  2.397724  68.547794  0.062492     0.051379   0.011114
# 37  2.424530  2.431429  70.097415  0.073637     0.055830   0.017806
# 38  2.436030  2.452351  66.121990  0.078609     0.060386   0.018223
# 39  2.433200  2.436869  50.894282  0.067306     0.061770   0.005536

# %%
mean_price = df3['Price'].mean()  # Normalize edilmeden önceki df3
std_price = df3['Price'].std()

print(mean_price, std_price)
# Out:
# 1.4954858947857935e-16 1.000131570291999

# %%
df3.to_csv('XRP_unnormalized.csv',index=False)

# %%
from sklearn.preprocessing import StandardScaler

# Normalleştirilecek sütunlar 'Change' ve 'Date' sütunu hariç her sütun normalize edilecek
normalize_columns = ['Price', 'Open', 'High', 'Low', 'Vol.', 'SMA_10', 'EMA_10', 'MACD', 'MACD_Signal', 'MACD_Diff']

# StandardScaler ile standartlaştırma
scaler = StandardScaler()
df3[normalize_columns] = scaler.fit_transform(df3[normalize_columns])

# Sonucu kontrol etme
print(df3.head())
# Out:
#         Date     Price      Open      High       Low      Vol.  Change %  \
# 0 2025-06-19  2.943189  2.990523  2.849499  3.127674 -0.525722     -1.06
# 1 2025-06-18  2.984205  2.970336  2.845053  3.079525 -0.446667      0.53
# 2 2025-06-17  2.963875  3.108961  2.975183  3.124864 -0.274607     -3.40
# 3 2025-06-16  3.099229  2.981948  3.111810  3.140976 -0.185850      3.20
# 4 2025-06-15  2.975645  2.935501  2.836503  3.115871 -0.619432      1.21
#
#      SMA_10    EMA_10     RSI_14      MACD  MACD_Signal  MACD_Diff
# 0  2.942716  2.953455  48.247141  0.988074      0.94818   0.317063
# 1  2.963253  2.960950  48.247141  0.988074      0.94818   0.317063
# 2  2.963312  2.963368  48.247141  0.988074      0.94818   0.317063
# 3  2.997227  2.990079  48.247141  0.988074      0.94818   0.317063
# 4  2.992825  2.989351  48.247141  0.988074      0.94818   0.317063

# %%
df3.to_csv("XRP_normalized.csv",index=False)

# %%
import pandas as pd

# future_predictions.csv dosyasını oku
future_df = pd.read_csv('future_predictions.csv')

# StandardScaler parametreleri
mean_price = 1.4954858947857935e-16  # ≈ 0
std_price = 1.000131570291999       # ≈ 1

# StandardScaler ters dönüşümü (gerekirse)
future_df['Original_Price'] = (future_df['Price'] * std_price) + mean_price

# Bugünün gerçek fiyatı
today_price = 2.14

# İlk tahmin ile gerçek fiyat arasındaki farkı hesapla
first_predicted_price = future_df['Original_Price'].iloc[0]
offset = first_predicted_price - today_price

# Tahminleri kaydırarak düzelt
future_df['Corrected_Price'] = future_df['Original_Price'] - offset

# Tarih formatını düzenle (saat kısmını kaldırmak için)
future_df['Date'] = pd.to_datetime(future_df['Date']).dt.strftime('%Y-%m-%d')

# Düzeltilmiş tahminleri ve tarihleri yeni bir CSV dosyasına yaz
future_df[['Date', 'Corrected_Price']].to_csv('corrected_future_predictions.csv', index=False)

print("Düzeltilmiş tahminler 'corrected_future_predictions.csv' dosyasına yazıldı.")
# Out:
# Düzeltilmiş tahminler 'corrected_future_predictions.csv' dosyasına yazıldı.
